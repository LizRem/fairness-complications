# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Data for 6 months
ethnicities = ['Black or Black British', 'Asian or Asian British', 'Any Other Ethnic Group', 'Mixed', 'Missing', 'Unknown']
sensitivity = [-0.05, -0.02, -0.07, -0.04, -0.36, -0.27]
specificity = [0.06, 0.06, 0.13, 0.19, 0.33, 0.22]
parity = [-0.07, -0.07, -0.16, -0.21, -0.39, -0.27]

# Confidence intervals
sensitivity_ci = [(-0.1, -0.01), (-0.07, 0.02), (-0.16, 0.01), (-0.21, 0.11), (-0.51, -0.2), (-0.47, -0.08)]
specificity_ci = [(0.04, 0.09), (0.04, 0.09), (0.1, 0.17), (0.12, 0.25), (0.3, 0.35), (0.17, 0.27)]
parity_ci = [(-0.09, -0.05), (-0.09, -0.05), (-0.19, -0.13), (-0.27, -0.14), (-0.41, -0.36), (-0.32, -0.23)]

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(ethnicities))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap')
ax.set_title('Gaps in Sensitivity, Specificity, and Parity by Ethnicity (6 Months)')
ax.set_xticks(x)
ax.set_xticklabels(ethnicities, rotation=45, ha='right')
ax.legend()

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Data for Black or Black British
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.05, 0.0, -0.0, -0.01]
specificity = [0.06, 0.05, 0.04, 0.04]
parity = [-0.07, -0.05, -0.04, -0.04]

# Confidence intervals
sensitivity_ci = [(-0.1, -0.01), (-0.04, 0.04), (-0.04, 0.03), (-0.05, 0.04)]
specificity_ci = [(0.04, 0.09), (0.02, 0.07), (0.01, 0.06), (0.02, 0.07)]
parity_ci = [(-0.09, -0.05), (-0.08, -0.03), (-0.06, -0.02), (-0.07, -0.02)]

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap')
ax.set_title('Black or Black British')
ax.set_xticks(x)
ax.set_xticklabels(time_frames)
ax.legend()

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.15, 0.15)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# %%
# Data for Missing ethnic group
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.36, -0.36, -0.1, 0.08]
specificity = [0.33, 0.37, 0.29, 0.23]
parity = [-0.39, -0.43, -0.35, -0.3]

# Confidence intervals
sensitivity_ci = [(-0.51, -0.2), (-0.5, -0.2), (-0.24, 0.04), (-0.04, 0.18)]
specificity_ci = [(0.3, 0.35), (0.35, 0.39), (0.26, 0.32), (0.21, 0.26)]
parity_ci = [(-0.41, -0.36), (-0.45, -0.41), (-0.37, -0.32), (-0.32, -0.28)]

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap', fontsize=12)
ax.set_title('Missing Ethnic Group', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(time_frames, fontsize=10)
ax.legend(fontsize=10)

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.6, 0.5)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Optionally, save the figure
# plt.savefig('missing_ethnic_group_gaps.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Asian or Asian British ethnic group
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.02, -0.04, -0.02, 0.01]
specificity = [0.06, 0.08, 0.03, 0.03]
parity = [-0.07, -0.09, -0.04, -0.03]

# Confidence intervals
sensitivity_ci = [(-0.07, 0.02), (-0.08, 0.0), (-0.06, 0.01), (-0.04, 0.05)]
specificity_ci = [(0.04, 0.09), (0.05, 0.1), (0.01, 0.05), (0.0, 0.05)]
parity_ci = [(-0.09, -0.05), (-0.11, -0.06), (-0.06, -0.02), (-0.05, -0.01)]

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap', fontsize=12)
ax.set_title('Asian or Asian British Group', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(time_frames, fontsize=10)
ax.legend(fontsize=10)

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.15, 0.15)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Optionally, save the figure
# plt.savefig('asian_or_asian_british_gaps.png', dpi=300, bbox_inches='tight')

# %%
# make grid of 6 plots

# Data for Any Other Ethnic Group
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.07, -0.08, -0.08, -0.01]
specificity = [0.13, 0.15, 0.11, 0.08]
parity = [-0.16, -0.18, -0.14, -0.11]

# Confidence intervals
sensitivity_ci = [(-0.16, 0.01), (-0.17, -0.0), (-0.17, -0.0), (-0.09, 0.07)]
specificity_ci = [(0.1, 0.17), (0.12, 0.18), (0.07, 0.14), (0.05, 0.11)]
parity_ci = [(-0.19, -0.13), (-0.21, -0.14), (-0.17, -0.1), (-0.14, -0.08)]

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='orange', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap', fontsize=12)
ax.set_title('Any Other Ethnic Group', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(time_frames, fontsize=10)
ax.legend(fontsize=10)

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.25, 0.25)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Optionally, save the figure
# plt.savefig('any_other_ethnic_group_gaps.png', dpi=300, bbox_inches='tight')

# %%
# Data for Mixed ethnic group
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.04, -0.1, 0.04, 0.01]
specificity = [0.19, 0.17, 0.1, 0.1]
parity = [-0.21, -0.19, -0.13, -0.14]

# Confidence intervals
sensitivity_ci = [(-0.21, 0.11), (-0.3, 0.08), (-0.12, 0.13), (-0.24, 0.17)]
specificity_ci = [(0.12, 0.25), (0.1, 0.23), (0.03, 0.17), (0.03, 0.16)]
parity_ci = [(-0.27, -0.14), (-0.25, -0.12), (-0.21, -0.06), (-0.2, -0.08)]

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='orange', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap', fontsize=12)
ax.set_title('Mixed Ethnic Group', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(time_frames, fontsize=10)
ax.legend(fontsize=10)

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.3, 0.3)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Optionally, save the figure
# plt.savefig('mixed_ethnic_group_gaps.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Unknown ethnic group
time_frames = ['6 months', '12 months', '36 months', '60 months']
sensitivity = [-0.27, -0.18, 0.06, -0.12]
specificity = [0.22, 0.18, 0.13, 0.11]
parity = [-0.27, -0.21, -0.18, -0.16]

# Confidence intervals
sensitivity_ci = [(-0.47, -0.08), (-0.34, -0.04), (-0.07, 0.13), (-0.32, 0.06)]
specificity_ci = [(0.17, 0.27), (0.13, 0.23), (0.08, 0.19), (0.07, 0.15)]
parity_ci = [(-0.32, -0.23), (-0.26, -0.16), (-0.23, -0.13), (-0.21, -0.12)]

# Set up the plot
fig, ax = plt.subplots(figsize=(12, 6))

# Set the width of each bar and the positions of the bars
width = 0.25
x = np.arange(len(time_frames))

# Create the bars
bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)

# Add confidence intervals
ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=5)
ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=5)
ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=5)

# Customize the plot
ax.set_ylabel('Gap', fontsize=12)
ax.set_title('Unknown Ethnic Group', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(time_frames, fontsize=10)
ax.legend(fontsize=10)

# Add a horizontal line at y=0
ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)

# Adjust y-axis limits to better show the data
ax.set_ylim(-0.5, 0.3)

# Adjust layout and display the plot
plt.tight_layout()
plt.show()

# Optionally, save the figure
# plt.savefig('unknown_ethnic_group_gaps.png', dpi=300, bbox_inches='tight')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to create a single plot
def create_plot(ax, data, title):
    time_frames, sensitivity, specificity, parity, sensitivity_ci, specificity_ci, parity_ci = data
    
    width = 0.25
    x = np.arange(len(time_frames))
    
    bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
    bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
    bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)
    
    ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=3)
    ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=3)
    ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=3)
    
    ax.set_title(title, fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(time_frames, fontsize=16, rotation=45)
    ax.tick_params(axis='y', labelsize=16)  # Add this line to set y-axis font size
    ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)
    ax.set_ylim(-0.55, 0.5)  # Adjust this range if needed

# Data for each ethnic group
groups_data = {
    "Black or Black British": (
        ['6m', '12m', '36m', '60m'],
        [-0.05, 0.0, -0.0, -0.01],
        [0.06, 0.05, 0.04, 0.04],
        [-0.07, -0.05, -0.04, -0.04],
        [(-0.1, -0.01), (-0.04, 0.04), (-0.04, 0.03), (-0.05, 0.04)],
        [(0.04, 0.09), (0.02, 0.07), (0.01, 0.06), (0.02, 0.07)],
        [(-0.09, -0.05), (-0.08, -0.03), (-0.06, -0.02), (-0.07, -0.02)]
    ),
    "Asian or Asian British": (
        ['6m', '12m', '36m', '60m'],
        [-0.02, -0.04, -0.02, 0.01],
        [0.06, 0.08, 0.03, 0.03],
        [-0.07, -0.09, -0.04, -0.03],
        [(-0.07, 0.02), (-0.08, 0.0), (-0.06, 0.01), (-0.04, 0.05)],
        [(0.04, 0.09), (0.05, 0.1), (0.01, 0.05), (0.0, 0.05)],
        [(-0.09, -0.05), (-0.11, -0.06), (-0.06, -0.02), (-0.05, -0.01)]
    ),
    "Any Other Ethnic Group": (
        ['6m', '12m', '36m', '60m'],
        [-0.07, -0.08, -0.08, -0.01],
        [0.13, 0.15, 0.11, 0.08],
        [-0.16, -0.18, -0.14, -0.11],
        [(-0.16, 0.01), (-0.17, -0.0), (-0.17, -0.0), (-0.09, 0.07)],
        [(0.1, 0.17), (0.12, 0.18), (0.07, 0.14), (0.05, 0.11)],
        [(-0.19, -0.13), (-0.21, -0.14), (-0.17, -0.1), (-0.14, -0.08)]
    ),
    "Mixed": (
        ['6m', '12m', '36m', '60m'],
        [-0.04, -0.1, 0.04, 0.01],
        [0.19, 0.17, 0.1, 0.1],
        [-0.21, -0.19, -0.13, -0.14],
        [(-0.21, 0.11), (-0.3, 0.08), (-0.12, 0.13), (-0.24, 0.17)],
        [(0.12, 0.25), (0.1, 0.23), (0.03, 0.17), (0.03, 0.16)],
        [(-0.27, -0.14), (-0.25, -0.12), (-0.21, -0.06), (-0.2, -0.08)]
    ),
    "Missing": (
        ['6m', '12m', '36m', '60m'],
        [-0.36, -0.36, -0.1, 0.08],
        [0.33, 0.37, 0.29, 0.23],
        [-0.39, -0.43, -0.35, -0.3],
        [(-0.51, -0.2), (-0.5, -0.2), (-0.24, 0.04), (-0.04, 0.18)],
        [(0.3, 0.35), (0.35, 0.39), (0.26, 0.32), (0.21, 0.26)],
        [(-0.41, -0.36), (-0.45, -0.41), (-0.37, -0.32), (-0.32, -0.28)]
    ),
    "Unknown": (
        ['6m', '12m', '36m', '60m'],
        [-0.27, -0.18, 0.06, -0.12],
        [0.22, 0.18, 0.13, 0.11],
        [-0.27, -0.21, -0.18, -0.16],
        [(-0.47, -0.08), (-0.34, -0.04), (-0.07, 0.13), (-0.32, 0.06)],
        [(0.17, 0.27), (0.13, 0.23), (0.08, 0.19), (0.07, 0.15)],
        [(-0.32, -0.23), (-0.26, -0.16), (-0.23, -0.13), (-0.21, -0.12)]
    )
}

# Create the grid of plots
fig, axs = plt.subplots(2, 3, figsize=(18, 12))
fig.suptitle('Gaps in Sensitivity, Specificity, and Parity by Ethnic Group for Nephropathy', fontsize=20)

for ax, (group, data) in zip(axs.flatten(), groups_data.items()):
    create_plot(ax, data, group)

# Add a common legend
handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, fontsize=16)

# Adjust layout and display the plot
plt.tight_layout()
plt.subplots_adjust(bottom=0.1)  # Make room for the legend

# Optionally, save the figure
plt.savefig('ethnic_groups_gaps_grid_nephropathy.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
## Neuropathy

# %%
def create_plot(ax, data, title):
    time_frames, sensitivity, specificity, parity, sensitivity_ci, specificity_ci, parity_ci = data
    
    width = 0.25
    x = np.arange(len(time_frames))
    
    bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
    bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
    bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)
    
    ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=3)
    ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=3)
    ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=3)
    
    ax.set_title(title, fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(time_frames, fontsize=16, rotation=45)
    ax.tick_params(axis='y', labelsize=16)
    ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)
    ax.set_ylim(-0.8, 0.4)  # Adjusted based on the new data range

# Data for each ethnic group
groups_data = {
    "Black or Black British": (
        ['6m', '12m', '36m', '60m'],
        [0.00, -0.03, 0.05, -0.02],
        [0.06, 0.05, 0.04, 0.04],
        [-0.06, -0.06, -0.04, -0.06],
        [(-0.08, 0.08), (-0.12, 0.04), (-0.03, 0.12), (-0.09, 0.07)],
        [(0.04, 0.08), (0.02, 0.07), (0.02, 0.06), (0.02, 0.06)],
        [(-0.08, -0.04), (-0.08, -0.04), (-0.06, -0.02), (-0.08, -0.03)]
    ),
    "Asian or Asian British": (
        ['6m', '12m', '36m', '60m'],
        [-0.05, -0.12, -0.06, -0.04],
        [0.09, 0.08, 0.08, 0.06],
        [-0.10, -0.10, -0.09, -0.07],
        [(-0.13, 0.02), (-0.20, -0.04), (-0.14, 0.02), (-0.13, 0.04)],
        [(0.07, 0.11), (0.06, 0.10), (0.06, 0.10), (0.04, 0.07)],
        [(-0.12, -0.08), (-0.12, -0.08), (-0.11, -0.07), (-0.09, -0.05)]
    ),
    "Any Other Ethnic Group": (
        ['6m', '12m', '36m', '60m'],
        [-0.15, -0.08, 0.05, -0.11],
        [0.08, 0.07, 0.08, 0.07],
        [-0.10, -0.09, -0.09, -0.09],
        [(-0.31, 0.02), (-0.22, 0.05), (-0.12, 0.20), (-0.28, 0.06)],
        [(0.05, 0.11), (0.04, 0.11), (0.04, 0.11), (0.04, 0.10)],
        [(-0.13, -0.07), (-0.12, -0.06), (-0.12, -0.06), (-0.12, -0.06)]
    ),
    "Mixed": (
        ['6m', '12m', '36m', '60m'],
        [-0.46, -0.05, 0.26, 0.04],
        [0.09, 0.08, 0.05, 0.03],
        [-0.12, -0.09, -0.06, -0.06],
        [(-0.77, -0.04), (-0.37, 0.22), (0.23, 0.32), (-0.33, 0.26)],
        [(0.02, 0.15), (0.02, 0.15), (-0.01, 0.11), (-0.03, 0.09)],
        [(-0.18, -0.06), (-0.16, -0.03), (-0.13, 0.00), (-0.12, 0.01)]
    ),
    "Missing": (
        ['6m', '12m', '36m', '60m'],
        [-0.16, -0.02, -0.24, -0.06],
        [0.17, 0.20, 0.15, 0.16],
        [-0.19, -0.23, -0.18, -0.20],
        [(-0.49, 0.13), (-0.39, 0.24), (-0.56, 0.07), (-0.41, 0.25)],
        [(0.14, 0.19), (0.17, 0.22), (0.13, 0.18), (0.14, 0.19)],
        [(-0.22, -0.17), (-0.25, -0.20), (-0.21, -0.16), (-0.22, -0.18)]
    ),
    "Unknown": (
        ['6m', '12m', '36m', '60m'],
        [-0.25, -0.11, -0.31, 0.21],
        [0.13, 0.11, 0.12, 0.10],
        [-0.15, -0.13, -0.15, -0.12],
        [(-0.63, 0.13), (-0.46, 0.21), (-0.72, 0.06), (0.18, 0.27)],
        [(0.08, 0.18), (0.06, 0.15), (0.07, 0.16), (0.05, 0.14)],
        [(-0.20, -0.11), (-0.18, -0.08), (-0.19, -0.10), (-0.17, -0.09)]
    )
}

# Create the grid of plots
fig, axs = plt.subplots(2, 3, figsize=(20, 14))
fig.suptitle('Gaps in Sensitivity, Specificity, and Parity by Ethnic Group for Neuropathy', fontsize=20)

for ax, (group, data) in zip(axs.flatten(), groups_data.items()):
    create_plot(ax, data, group)

# Add a common legend
handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, fontsize=16)

# Adjust layout and display the plot
plt.tight_layout()
plt.subplots_adjust(bottom=0.1, top=0.93)

plt.savefig('ethnic_groups_gaps_grid_neuropathy.png', dpi=300, bbox_inches='tight')

plt.show()

# %%
def create_plot(ax, data, title):
    time_frames, sensitivity, specificity, parity, sensitivity_ci, specificity_ci, parity_ci = data
    
    width = 0.25
    x = np.arange(len(time_frames))
    
    bars1 = ax.bar(x - width, sensitivity, width, label='Sensitivity', color='blue', alpha=0.7)
    bars2 = ax.bar(x, specificity, width, label='Specificity', color='purple', alpha=0.7)
    bars3 = ax.bar(x + width, parity, width, label='Parity', color='red', alpha=0.7)
    
    ax.errorbar(x - width, sensitivity, yerr=np.abs(np.array(sensitivity_ci).T - sensitivity), fmt='none', color='black', capsize=3)
    ax.errorbar(x, specificity, yerr=np.abs(np.array(specificity_ci).T - specificity), fmt='none', color='black', capsize=3)
    ax.errorbar(x + width, parity, yerr=np.abs(np.array(parity_ci).T - parity), fmt='none', color='black', capsize=3)
    
    ax.set_title(title, fontsize=16)
    ax.set_xticks(x)
    ax.set_xticklabels(time_frames, fontsize=16, rotation=45)
    ax.tick_params(axis='y', labelsize=16)
    ax.axhline(y=0, color='gray', linestyle='--', linewidth=0.8)
    ax.set_ylim(-0.3, 0.3)  # Adjusted based on the new data range

# Data for each ethnic group
groups_data = {
    "Black or Black British": (
        ['6m', '12m', '36m', '60m'],
        [-0.04, 0.02, -0.03, 0.01],
        [-0.02, -0.03, -0.01, -0.04],
        [0.03, 0.04, 0.01, 0.05],
        [(-0.08, -0.00), (-0.02, 0.06), (-0.07, 0.00), (-0.03, 0.04)],
        [(-0.04, 0.01), (-0.05, -0.00), (-0.03, 0.02), (-0.06, -0.01)],
        [(0.00, 0.05), (0.02, 0.07), (-0.01, 0.04), (0.02, 0.07)]
    ),
    "Asian or Asian British": (
        ['6m', '12m', '36m', '60m'],
        [0.02, 0.05, 0.00, 0.05],
        [-0.05, -0.05, -0.06, -0.06],
        [0.08, 0.08, 0.08, 0.09],
        [(-0.01, 0.05), (0.01, 0.08), (-0.03, 0.03), (0.02, 0.08)],
        [(-0.08, -0.03), (-0.07, -0.02), (-0.08, -0.04), (-0.08, -0.04)],
        [(0.06, 0.10), (0.06, 0.10), (0.05, 0.10), (0.06, 0.11)]
    ),
    "Any Other Ethnic Group": (
        ['6m', '12m', '36m', '60m'],
        [-0.03, 0.02, 0.03, 0.00],
        [-0.02, -0.03, 0.01, -0.02],
        [0.01, 0.02, 0.00, 0.03],
        [(-0.09, 0.03), (-0.04, 0.08), (-0.02, 0.08), (-0.05, 0.06)],
        [(-0.05, 0.02), (-0.07, 0.01), (-0.03, 0.04), (-0.05, 0.02)],
        [(-0.03, 0.04), (-0.02, 0.05), (-0.03, 0.04), (-0.01, 0.06)]
    ),
    "Mixed": (
        ['6m', '12m', '36m', '60m'],
        [-0.01, -0.06, -0.03, 0.04],
        [-0.06, -0.05, 0.00, -0.05],
        [0.06, 0.02, -0.00, 0.06],
        [(-0.13, 0.10), (-0.21, 0.09), (-0.16, 0.07), (-0.05, 0.12)],
        [(-0.14, 0.02), (-0.13, 0.03), (-0.07, 0.07), (-0.12, 0.02)],
        [(-0.00, 0.14), (-0.05, 0.09), (-0.07, 0.07), (-0.01, 0.13)]
    ),
    "Missing": (
        ['6m', '12m', '36m', '60m'],
        [0.06, 0.11, 0.03, 0.08],
        [-0.23, -0.25, -0.13, -0.10],
        [0.22, 0.23, 0.12, 0.10],
        [(0.02, 0.10), (0.07, 0.16), (-0.01, 0.07), (0.04, 0.12)],
        [(-0.26, -0.19), (-0.28, -0.21), (-0.17, -0.10), (-0.14, -0.07)],
        [(0.19, 0.25), (0.20, 0.26), (0.09, 0.15), (0.06, 0.13)]
    ),
    "Unknown": (
        ['6m', '12m', '36m', '60m'],
        [-0.10, 0.11, -0.01, 0.10],
        [-0.03, -0.08, -0.03, -0.04],
        [-0.00, 0.07, -0.00, 0.03],
        [(-0.22, 0.01), (0.02, 0.18), (-0.11, 0.09), (0.04, 0.15)],
        [(-0.09, 0.03), (-0.13, -0.02), (-0.08, 0.02), (-0.09, 0.02)],
        [(-0.06, 0.05), (0.01, 0.12), (-0.06, 0.05), (-0.02, 0.08)]
    )
}

# Create the grid of plots
fig, axs = plt.subplots(2, 3, figsize=(20, 14))
fig.suptitle('Gaps in Sensitivity, Specificity, and Parity by Ethnic Group for Retinopathy', fontsize=20)

for ax, (group, data) in zip(axs.flatten(), groups_data.items()):
    create_plot(ax, data, group)

# Add a common legend
handles, labels = axs[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='lower center', ncol=3, fontsize=16)

# Adjust layout and display the plot
plt.tight_layout()
plt.subplots_adjust(bottom=0.1, top=0.93)


plt.savefig('ethnic_groups_gaps_grid_retinopathy.png', dpi=300, bbox_inches='tight')

plt.show()

# Optionally, save the figure
